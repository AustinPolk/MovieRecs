# %%
# %load_ext autoreload
# %autoreload 2

# %%
from keras import activations

hyperparameters = {
    "UseAdjectives": False,
    "MinKeywordOccurrences": 10,
    "MaxKeywordOccurrences": 500,
    "EncoderHiddenDimensions": 64,
    "EncoderLatentDimensions": 8,
    "EncoderHiddenActivation": activations.relu,
    "EncoderLatentActivation": activations.relu,
    "DecoderHiddenDimensions": 64,
    "DecoderHiddenActivation": activations.relu,
    "DecoderFinalActivation": activations.sigmoid,
    "EncoderEpochs" : 75,
    "ClassifierMaxDepth": 5,
    "ClassifierEstimators": 10
}

# %%
import os

dataFiles = []
for root, dirs, files in os.walk("Data2"):
    for file in files:
        path = os.path.join(root, file)
        dataFiles.append(path)

# %%
from movie_reviews import MovieReviews

mr = MovieReviews(hyperparameters)

mr.train_encoder(dataFiles)
mr.train_user_classifier("Trevor.txt")
# Out:
# Epoch 1/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1521
# Epoch 2/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0310
# Epoch 3/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296
# Epoch 4/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296
# Epoch 5/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0297
# Epoch 6/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0295
# Epoch 7/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0290
# Epoch 8/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0286
# Epoch 9/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282
# Epoch 10/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0289
# Epoch 11/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0293
# Epoch 12/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0290
# Epoch 13/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0294
# Epoch 14/75
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0292
# Epoch 15/75
# ...

# %%
def make_prediction(movie_title, movie_year):
    prediction, probability = mr.predict(movie_title, movie_year)
    if prediction != None:
        if prediction[0]:
            print(f"You're gonna love it! ({probability[0][1] * 100}% confident)")
        else:
            print(f"Maybe pick a different one... ({probability[0][0] * 100}% confident)")

def session_loop(n):
    for i in range(n):
        title = input("What movie are you interested in? ")
        year = input("When was it released? (Enter -1 if you don't know) ")
        print("Let me think about it...")
        make_prediction(title, year)
        print()

# %%
session_loop(3)
# Out:
# Let me think about it...
# Searching for Iron man (2008)...
# Found under id=0371746
# Maybe pick a different one... (80.0% confident)
#
# Let me think about it...
# Searching for Iron man (-1)...
# Found under id=0371746
# Maybe pick a different one... (80.0% confident)
#
# Let me think about it...
# Searching for Iron man 2 (-1)...
# Found under id=1228705
# You're gonna love it! (75.0% confident)

# %%
mr.KeywordList
# Out:
# ['cocaine',
#  'business',
#  'proceed',
#  'performance',
#  'shark',
#  'jewelry',
#  'protest',
#  'tv',
#  'loan',
#  'star',
#  'office',
#  'pawn',
#  'split',
#  'gambling',
#  'bid',
#  'girlfriend',
#  'auction',
#  'insist',
#  'cancel',
#  'winning',
#  'sale',
#  'reconcile',
#  'top',
#  'luck',
#  'snort',
#  'addict',
#  'dinner',
#  'anger',
#  'game',
#  'plea',
#  'retrieve',
#  'track',
#  'backfire',
#  'bodyguard',
#  'trunk',
#  'struggle',
#  'chance',
#  'demand',
#  'security',
#  'fail',
#  'strip',
#  'owe',
#  'threaten',
#  'apartment',
#  'loot',
#  'win',
#  'miner',
#  'basketball',
#  'store',
#  'price',
#  'betray',
#  'host',
#  'employee',
#  'marriage',
#  'accept',
#  'lock',
#  'free',
#  'reject',
#  'mine',
#  'purchase',
#  'debt',
#  'divorce',
#  'tear',
#  'law',
#  'estimate',
#  'obsess',
#  'thug',
#  'casino',
#  'travel',
#  'helicopter',
#  'assault',
#  'ring',
#  'comfort',
#  'ambush',
#  'bathroom',
#  'associate',
#  'pursue',
# ...
